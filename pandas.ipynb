# %%
import pandas as pd
import requests

# %%
res = requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')
js = res.json()
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47082',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47082/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47082/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47082/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47082',
#   'id': 1243917106,
#   'node_id': 'PR_kwDOAA0YD844Ovn_',
#   'number': 47082,
#   'title': 'BUG: Fix `set_sticky` background',
#   'user': {'login': 'ShawnZhong',
#    'id': 6421097,
#    'node_id': 'MDQ6VXNlcjY0MjEwOTc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6421097?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ShawnZhong',
#    'html_url': 'https://github.com/ShawnZhong',
#    'followers_url': 'https://api.github.com/users/ShawnZhong/followers',
# ...

# %%
js[0]["url"]
# Out:
# 'https://api.github.com/repos/pandas-dev/pandas/issues/47082'

# %%
for i in range(len(js)):
    print(js[i]["url"])
# Out:
# https://api.github.com/repos/pandas-dev/pandas/issues/47082
# https://api.github.com/repos/pandas-dev/pandas/issues/47081
# https://api.github.com/repos/pandas-dev/pandas/issues/47080
# https://api.github.com/repos/pandas-dev/pandas/issues/47079
# https://api.github.com/repos/pandas-dev/pandas/issues/47078
# https://api.github.com/repos/pandas-dev/pandas/issues/47077
# https://api.github.com/repos/pandas-dev/pandas/issues/47076
# https://api.github.com/repos/pandas-dev/pandas/issues/47075
# https://api.github.com/repos/pandas-dev/pandas/issues/47074
# https://api.github.com/repos/pandas-dev/pandas/issues/47073
# https://api.github.com/repos/pandas-dev/pandas/issues/47072
# https://api.github.com/repos/pandas-dev/pandas/issues/47071
# https://api.github.com/repos/pandas-dev/pandas/issues/47070
# https://api.github.com/repos/pandas-dev/pandas/issues/47066
# https://api.github.com/repos/pandas-dev/pandas/issues/47064
# https://api.github.com/repos/pandas-dev/pandas/issues/47061
# ...

# %%
df = pd.DataFrame(js)
df.head()
# Out:
#   active_lock_reason assignee assignees author_association  \
# 0               None     None        []        CONTRIBUTOR
# 1               None     None        []             MEMBER
# 2               None     None        []             MEMBER
# 3               None     None        []             MEMBER
# 4               None     None        []             MEMBER
#
#                                                 body closed_at  comments  \
# 0  - [x] closes #46984 (Replace xxxx with the Git...      None         0
# 1  - [ ] closes #xxxx (Replace xxxx with the Gith...      None         0
# 2  Part of #44642\r\n\r\n- [ ] [Tests added and p...      None         0
# 3  This is similar to an example in the `DataFram...      None         0
# 4  - [x] closes #46995 (Replace xxxx with the Git...      None         1
#
#                                         comments_url            created_at  \
# 0  https://api.github.com/repos/pandas-dev/pandas...  2022-05-21T08:35:28Z
# ...

# %%
df1 = df.to_csv("my_json.csv")

# %%
for i in range(len(js)):
    df3 = pd.DataFrame(js[i]["user"])
df3

# --- > Dictionary annot be converted to dataframe
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5420/3862088497.py in <module>
#       1 for i in range(len(js)):
# ----> 2     df3 = pd.DataFrame(js[i]["user"])
#       3 df3
#
# ~\anaconda3\envs\pytorchenv\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\envs\pytorchenv\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# ...

# %%
l = []
for i in range(len(js)):
    l.append(js[i]["user"])
df3 = pd.DataFrame(l)
df3.head()
# Out:
#                                           avatar_url  \
# 0  https://avatars.githubusercontent.com/u/642109...
# 1  https://avatars.githubusercontent.com/u/479632...
# 2  https://avatars.githubusercontent.com/u/455624...
# 3  https://avatars.githubusercontent.com/u/455624...
# 4  https://avatars.githubusercontent.com/u/455624...
#
#                                           events_url  \
# 0  https://api.github.com/users/ShawnZhong/events...
# 1  https://api.github.com/users/lithomas1/events{...
# 2  https://api.github.com/users/rhshadrach/events...
# 3  https://api.github.com/users/rhshadrach/events...
# 4  https://api.github.com/users/rhshadrach/events...
#
#                                        followers_url  \
# 0  https://api.github.com/users/ShawnZhong/followers
# 1   https://api.github.com/users/lithomas1/followers
# 2  https://api.github.com/users/rhshadrach/followers
# 3  https://api.github.com/users/rhshadrach/followers
# ...

# %%
js1 = pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')
data = pd.DataFrame.from_records(js1["user"])
data.head()
# Out:
#                                           avatar_url  \
# 0  https://avatars.githubusercontent.com/u/642109...
# 1  https://avatars.githubusercontent.com/u/479632...
# 2  https://avatars.githubusercontent.com/u/455624...
# 3  https://avatars.githubusercontent.com/u/455624...
# 4  https://avatars.githubusercontent.com/u/455624...
#
#                                           events_url  \
# 0  https://api.github.com/users/ShawnZhong/events...
# 1  https://api.github.com/users/lithomas1/events{...
# 2  https://api.github.com/users/rhshadrach/events...
# 3  https://api.github.com/users/rhshadrach/events...
# 4  https://api.github.com/users/rhshadrach/events...
#
#                                        followers_url  \
# 0  https://api.github.com/users/ShawnZhong/followers
# 1   https://api.github.com/users/lithomas1/followers
# 2  https://api.github.com/users/rhshadrach/followers
# 3  https://api.github.com/users/rhshadrach/followers
# ...

# %%
## ---> list can be converted to dataframe

# %%
df = pd.read_csv("titanic_train.csv")
df.head()
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#       sex   age  sibsp  parch  ticket     fare cabin embarked boat  body  \
# 0  female   NaN      0      0  335432   7.7333   NaN        Q   13   NaN
# 1    male  38.0      0      0  315089   8.6625   NaN        S  NaN   NaN
# 2  female  30.0      1      1  345773  24.1500   NaN        S  NaN   NaN
# 3  female  54.0      1      3   29105  23.0000   NaN        S    4   NaN
# 4    male  40.0      0      0   28221  13.0000   NaN        S  NaN   NaN
#
#                   home.dest  survived
# ...

# %%
 df["fare"].max()
# Out:
# 512.3292

# %%
df[df["fare"] == df["fare"].max()]["name"]
# Out:
# 60     Cardeza, Mrs. James Warburton Martinez (Charlo...
# 790                               Lesurer, Mr. Gustave J
# 796                   Cardeza, Mr. Thomas Drake Martinez
# Name: name, dtype: object
